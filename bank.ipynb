# %%
# import file from system
import pandas as pd
data = pd.read_csv("C:/Users/DELL/Desktop/Programming/bank-full.csv", delimiter = ";")

# %%
data.head(30)
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married    unknown      no     1506     yes   no
# 4    33       unknown    single    unknown      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...

# %%
data.shape
# Out:
# (45211, 17)

# %%
data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
data.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
dup = data.duplicated(keep="first")
data_2 = data[-dup]

# %%
data_2.shape
# Out:
# (45211, 17)

# %%
#convert "non-numeric" values to categorical values
from sklearn import preprocessing
from sklearn import utils
lab = preprocessing.LabelEncoder()

job_transformed = lab.fit_transform(data_2["job"])
data_2["Job"] = job_transformed

marital_transformed = lab.fit_transform(data_2["marital"])
data_2["Marital"] = marital_transformed

education_transformed = lab.fit_transform(data_2["education"])
data_2["Education"] = education_transformed

default_transformed = lab.fit_transform(data_2["default"])
data_2["Default"] = default_transformed

housing_transformed = lab.fit_transform(data_2["housing"])
data_2["Housing"] = housing_transformed

loan_transformed = lab.fit_transform(data_2["loan"])
data_2["Loan"] = loan_transformed

contact_transformed = lab.fit_transform(data_2["contact"])
data_2["Contact"] = contact_transformed

month_transformed = lab.fit_transform(data_2["month"])
data_2["Month"] = month_transformed

poutcome_transformed = lab.fit_transform(data_2["poutcome"])
data_2["Poutcome"] = poutcome_transformed

y_transformed = lab.fit_transform(data_2["y"])
data_2["Y"] = y_transformed

# %%
data_2.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y', 'Job', 'Marital', 'Education', 'Default',
#        'Housing', 'Loan', 'Contact', 'Month', 'Poutcome', 'Y'],
#       dtype='object')

# %%
data_3 = data_2[['age','balance', 'day','duration', 'campaign', 'pdays',
       'previous', 'Job', 'Marital', 'Education', 'Default',
       'Housing', 'Loan', 'Contact', 'Month', 'Poutcome', 'Y']]

# %%
data_3.head(30)
# Out:
#     age  balance  day  duration  campaign  pdays  previous  Job  Marital  \
# 0    58     2143    5       261         1     -1         0    4        1
# 1    44       29    5       151         1     -1         0    9        2
# 2    33        2    5        76         1     -1         0    2        1
# 3    47     1506    5        92         1     -1         0    1        1
# 4    33        1    5       198         1     -1         0   11        2
# 5    35      231    5       139         1     -1         0    4        1
# 6    28      447    5       217         1     -1         0    4        2
# 7    42        2    5       380         1     -1         0    2        0
# 8    58      121    5        50         1     -1         0    5        1
# 9    43      593    5        55         1     -1         0    9        2
# 10   41      270    5       222         1     -1         0    0        0
# 11   29      390    5       137         1     -1         0    0        2
# ...

# %%
for i in data_3.columns:
    print(i, ":", data_3[i].unique())
# Out:
# age : [58 44 33 47 35 28 42 43 41 29 53 57 51 45 60 56 32 25 40 39 52 46 36 49
#  59 37 50 54 55 48 24 38 31 30 27 34 23 26 61 22 21 20 66 62 83 75 67 70
#  65 68 64 69 72 71 19 76 85 63 90 82 73 74 78 80 94 79 77 86 95 81 18 89
#  84 87 92 93 88]
# balance : [ 2143    29     2 ...  8205 14204 16353]
# day : [ 5  6  7  8  9 12 13 14 15 16 19 20 21 23 26 27 28 29 30  2  3  4 11 17
#  18 24 25  1 10 22 31]
# duration : [ 261  151   76 ... 1298 1246 1556]
# campaign : [ 1  2  3  5  4  6  7  8  9 10 11 12 13 19 14 24 16 32 18 22 15 17 25 21
#  43 51 63 41 26 28 55 50 38 23 20 29 31 37 30 46 27 58 33 35 34 36 39 44]
# pdays : [ -1 151 166  91  86 143 147  89 140 176 101 174 170 167 195 165 129 188
#  196 172 118 119 104 171 117 164 132 131 123 159 186 111 115 116 173 178
#  110 152  96 103 150 175 193 181 185 154 145 138 126 180 109 158 168  97
#  182 127 130 194 125 105 102  26 179  28 183 155 112 120 137 124 187 190
# ...

# %%
# Diagrammatic Representation of the data using a density plot
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
data_3.plot(kind = "density", subplots = True, layout = (6,3), sharex = False)
plt.gcf().set_size_inches(15,15)
plt.show()

# %%
data_3.describe().T
# Out:
#              count         mean          std     min    25%    50%     75%  \
# age        45211.0    40.936210    10.618762    18.0   33.0   39.0    48.0
# balance    45211.0  1362.272058  3044.765829 -8019.0   72.0  448.0  1428.0
# day        45211.0    15.806419     8.322476     1.0    8.0   16.0    21.0
# duration   45211.0   258.163080   257.527812     0.0  103.0  180.0   319.0
# campaign   45211.0     2.763841     3.098021     1.0    1.0    2.0     3.0
# pdays      45211.0    40.197828   100.128746    -1.0   -1.0   -1.0    -1.0
# previous   45211.0     0.580323     2.303441     0.0    0.0    0.0     0.0
# Job        45211.0     4.339762     3.272657     0.0    1.0    4.0     7.0
# Marital    45211.0     1.167725     0.608230     0.0    1.0    1.0     2.0
# Education  45211.0     1.224813     0.747997     0.0    1.0    1.0     2.0
# Default    45211.0     0.018027     0.133049     0.0    0.0    0.0     0.0
# ...

# %%
data_3_columns = data_3.columns

# %%
from sklearn.preprocessing import MinMaxScaler

#Normalize data
data_3_array = data_3.values
X = data_3_array[:,0:-1]
Y = data_3_array[:,-1]
demo = MinMaxScaler(feature_range=(0,1))
new_data = demo.fit_transform(X)
New_data = pd.DataFrame(new_data)
New_data.columns = data_3_columns[:-1]

# %%
New_data["Y"] = data_3["Y"]

# %%
New_data.head(20)
# Out:
#          age   balance       day  duration  campaign  pdays  previous  \
# 0   0.519481  0.092259  0.133333  0.053070       0.0    0.0       0.0
# 1   0.337662  0.073067  0.133333  0.030704       0.0    0.0       0.0
# 2   0.194805  0.072822  0.133333  0.015453       0.0    0.0       0.0
# 3   0.376623  0.086476  0.133333  0.018707       0.0    0.0       0.0
# 4   0.194805  0.072812  0.133333  0.040260       0.0    0.0       0.0
# 5   0.220779  0.074901  0.133333  0.028264       0.0    0.0       0.0
# 6   0.129870  0.076862  0.133333  0.044124       0.0    0.0       0.0
# 7   0.311688  0.072822  0.133333  0.077267       0.0    0.0       0.0
# 8   0.519481  0.073902  0.133333  0.010167       0.0    0.0       0.0
# 9   0.324675  0.078187  0.133333  0.011183       0.0    0.0       0.0
# 10  0.298701  0.075255  0.133333  0.045140       0.0    0.0       0.0
# 11  0.142857  0.076344  0.133333  0.027857       0.0    0.0       0.0
# ...

# %%
# Diagrammatic Representation of the data using a density plot
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
New_data.plot(kind = "density", subplots = True, layout = (6,3), sharex = False)
plt.gcf().set_size_inches(15,15)
plt.show()

# %%
# feature selection
from sklearn.feature_selection import RFE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
array = New_data.values
x = array[:,0:-1]
y = array[:,-1]
model = LinearDiscriminantAnalysis()#algorithm

rfe = RFE(model)

fit = rfe.fit(x,y) #The model is going to school(Brainy Otunba) to learn the concept of the data

model.fit(x,y)
score = model.score(x,y)

print("Num Features: {}". format(fit.n_features_))
print("Selected Features{}:". format(fit.support_))
print("Features Ranking: {}". format(fit.ranking_))
# Out:
# Num Features: 8
# Selected Features[False  True False  True  True  True  True False False False False  True
#  False  True False  True]:
# Features Ranking: [5 1 8 1 1 1 1 9 6 2 7 1 4 1 3 1]

# %%
selected_features = list(New_data.columns[:-1][fit.support_])
selected_features.extend("Y")

# %%
bank_data = New_data[selected_features]

# %%
bank_data
# Out:
#         balance  duration  campaign     pdays  previous  Housing  Contact  \
# 0      0.092259  0.053070  0.000000  0.000000  0.000000      1.0      1.0
# 1      0.073067  0.030704  0.000000  0.000000  0.000000      1.0      1.0
# 2      0.072822  0.015453  0.000000  0.000000  0.000000      1.0      1.0
# 3      0.086476  0.018707  0.000000  0.000000  0.000000      1.0      1.0
# 4      0.072812  0.040260  0.000000  0.000000  0.000000      0.0      1.0
# ...         ...       ...       ...       ...       ...      ...      ...
# 45206  0.080293  0.198658  0.032258  0.000000  0.000000      0.0      0.0
# 45207  0.088501  0.092721  0.016129  0.000000  0.000000      0.0      0.0
# 45208  0.124689  0.229158  0.064516  0.212156  0.010909      0.0      0.0
# 45209  0.078868  0.103294  0.048387  0.000000  0.000000      0.0      0.5
# 45210  0.099777  0.073404  0.016129  0.216743  0.040000      0.0      0.0
#
#        Poutcome  Y
# 0      1.000000  0
# 1      1.000000  0
# ...

# %%
import statistics as stats
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import sklearn

bank_data_array = bank_data.values
X = bank_data_array[:,0:-1]
Y = bank_data_array[:,-1]

num_fold = 2
models = []
Names = []
Results = []
Scoring = 'accuracy'
models.append(('LOR',LogisticRegression()))
models.append(('DTC',DecisionTreeClassifier()))
models.append(('KNC',KNeighborsClassifier()))
models.append(('GNB',GaussianNB()))
models.append(('LDA',LinearDiscriminantAnalysis()))

sk = sorted(sklearn.metrics.SCORERS.keys())

for name,model in models:
    kfold = KFold(n_splits = num_fold, shuffle =True, random_state = num_fold)
    cv_results = cross_val_score(model,X,Y,cv=kfold)
    Names.append(name)
    Results.append(cv_results)
    Final_Result = (name,stats.mean(cv_results),cv_results.std())
    print(Final_Result)
# Out:
# ('LOR', 0.8903585139933299, 0.0030345435826228772)
# ('DTC', 0.8563402039348145, 0.002326839046112956)
# ('KNC', 0.892216416079513, 0.0032841614797930003)
# ('GNB', 0.8453031251594466, 0.006591974106302963)
# ('LDA', 0.8914423303287841, 0.0019703557465715143)

# %%
# D = []
# for a,b in zip(range(2,21),range(2,21)): 
#     bank_model = LinearDiscriminantAnalysis()
#     kfold = KFold(n_splits = a, shuffle =True, random_state = b)
#     results = cross_val_score(model,X,Y,cv=kfold)
#     predict = cross_val_predict(model,X,Y,cv=kfold) 
#     c = stats.mean(results)
#     D.append(c)
# D.index(max(D))
# for a,b in zip(range(2,21),range(2,21)):
#     print(a)

# %%
bank_data_array = bank_data.values
X = bank_data_array[:,0:-1]
Y = bank_data_array[:,-1]
bank_model = LinearDiscriminantAnalysis()
kfold = KFold(n_splits = num_fold, shuffle =True, random_state = 4)
results = cross_val_score(model,X,Y,cv=kfold)
predict = cross_val_predict(model,X,Y,cv=kfold)

# %%
stats.mean(results)
# Out:
# 0.8914423303287841

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predict,Y)
# Out:
# 0.10855765189887417
